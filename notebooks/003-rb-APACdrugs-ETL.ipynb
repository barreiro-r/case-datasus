# %% [markdown]
# # ETL DataSUS APAC Drugs
#
# ELT com PySUS
#
# Author: Rodrigo Barreiro

# %% [markdown]
# # Testing if PySUS is working

# %%
import pandas as pd
from collections import Counter
from pathlib import Path
import re
from pysus import SIA

# %%
sia = SIA().load() # Loads the files from DATASUS

# %%
sia.metadata

# %%
sia.groups

# %%
print(f'All files for APAC Medicamentos: {len(sia.get_files(["AM"]))}')

# %% [markdown]
# ## Calculating Files and Size

# %%
all_apac_quimio_sia = len(sia.get_files("AM", year=2022))
print(f'Number of files for AQ in 2022: {all_apac_quimio_sia}')

# %%
aq_files_2022 = sia.get_files("AM", year=2022)
Counter([ str(x)[2:4] for x in aq_files_2022 ])

# %%
# Countig file size
files = sia.get_files("AM", year=2022)
sizes = [ sia.describe(my_file)['size'] for my_file in files ]


# Example list
sizes = ['37.9 kB', '1.2 MB', '550 B', '2.1 MB', '900 kB']

# Conversion to bytes
unit_multipliers = {
    'B': 1,
    'kB': 1024,
    'MB': 1024 ** 2,
    'GB': 1024 ** 3
}

total_bytes = 0

for s in sizes:
    match = re.match(r'([\d.]+)\s*(B|kB|MB|GB)', s)
    if match:
        number, unit = match.groups()
        bytes_size = float(number) * unit_multipliers[unit]
        total_bytes += bytes_size
    else:
        print(f"Unrecognized size format: {s}")

# Optional: convert back to human-readable
def human_readable(size_bytes):
    for unit in ['B', 'kB', 'MB', 'GB']:
        if size_bytes < 1024 or unit == 'GB':
            return f"{size_bytes:.2f} {unit}"
        size_bytes /= 1024

print(f"Total: {human_readable(total_bytes)}")
print("NOTE: This is the size of dbc file (compressed).")

# %% [markdown]
# ## Extract
# ### Downlaod all APAC drugs from 2022 of all BR States

# %%
# Download all files of 2022
# sia.download(files, local_dir='../data/raw/apac-am')

# %% [markdown]
# Check if all files were downloaded

# %%
download_dir = Path('../data/raw/apac-am')
all_downloaded_files = [f.name for f in download_dir.iterdir() if f.suffix == '.parquet']
print(f'All downloaded files: {len(all_downloaded_files)} of {all_apac_quimio_sia} of SIA')

# %% [markdown]
# ## Transform
# ### Convert to dataframe and merge all files into one

# %%
all_data_df_list = [ x.to_dataframe() for x in sia.download(files, local_dir='../data/raw/apac-am') ]

# %%
print("Check type:")
print([type(x) for x in all_data_df_list[:3]])
print('\n')
print("Check dataframe n:")
print(len(all_data_df_list))

# %%
# Concatenate to a single dataframe
combined_df = pd.concat(all_data_df_list, ignore_index=True)
del all_data_df_list

print(f"Rows (Atendimentos) {combined_df.shape[0]:,.0f} \nColumns (Campos) {combined_df.shape[1]:,.0f} ")

# %%
combined_df.to_csv('../data/interim/apac-am-2022-full.csv', index = False)

# %%
print(combined_df.columns.tolist())

# %%
combined_df.head(10)

# %% [markdown]
# ### Better naming

# %%
new_names_df = pd.read_csv('../data/external/better_names_apac_am.csv', sep = ';')

my_dict = new_names_df.set_index('original_name')['new_name'].to_dict()
my_dict

# %%
combined_df = combined_df.rename(columns=my_dict)
combined_df

# %%
selected_fields = ["numero_apac","procedimento_principal","valor_total_apac","codigo_uf_municipio","cns_paciente","idade","sexo","raca_cor","motivo_saida_permanencia","data_ocorrencia","cid_principal","peso","altura","indicador_transplante","quantidade_transplantes","indicador_gestante"]

combined_df = combined_df[selected_fields].copy()

# %%
combined_df.to_csv('../data/interim/apac-am-2022-short.csv', index = False)

# %% [markdown]
# ### Add CID

# %%
# combined_df = pd.read_csv('../data/interim/apac-am-2022-short.csv').sample(frac = 0.1, axis = 0)
combined_df = pd.read_csv('../data/interim/apac-am-2022-short.csv')

# %%
cid10_data = pd.read_csv('../data/external/CID-10-CATEGORIAS.CSV.utf8',sep = ';')
cid10_data = cid10_data[['CAT','DESCRICAO']]

cid10_data.rename(columns={"CAT": 'CID10', "DESCRICAO":"cid10_main_descricao"}, inplace=True)
cid10_data
# Out:
#      CID10                               cid10_main_descricao
# 0      A00                                             Cólera
# 1      A01                       Febres tifóide e paratifóide
# 2      A02                    Outras infecções por Salmonella
# 3      A03                                         Shiguelose
# 4      A04           Outras infecções intestinais bacterianas
# ...    ...                                                ...
# 2040   U80  Agente resistente à penicilina e antibióticos ...
# 2041   U81  Agente resistente à vancomicina e antibióticos...
# 2042   U88         Agente resistente a múltiplos antibióticos
# 2043   U89  Agente resistente a outros antibióticos e a an...
# 2044   U99                     CID 10ª Revisão não disponível
#
# [2045 rows x 2 columns]

# %%
combined_df['cid_principal_main_categ'] = combined_df['cid_principal'].str[:3]
combined_df['cid_principal_main_categ']
# Out:
# 0           F20
# 1           F20
# 2           E23
# 3           E22
# 4           E22
#            ...
# 27162599    E22
# 27162600    N18
# 27162601    E23
# 27162602    F20
# 27162603    G20
# Name: cid_principal_main_categ, Length: 27162604, dtype: object

# %%
combined_df = pd.merge(combined_df, cid10_data, how = 'left', left_on = 'cid_principal_main_categ', right_on = 'CID10')

# %%
# Output most common CID table to GPT create simple names
summary_cid = combined_df.groupby('cid10_main_descricao').size().reset_index(name='n').sort_values('n',  ascending=False).head(30)
# summary_cid.head(50).to_csv('../data/interim/top50cids.csv', index = False)   
combined_df
# Out:
#             numero_apac  procedimento_principal  valor_total_apac  \
# 0         1221200228260             604230028.0              0.00
# 1         1221200222231             604230028.0              0.00
# 2         1221200245089             604100019.0              0.00
# 3         1221200245232             604110030.0            256.58
# 4         1221200251854             604110030.0            256.58
# ...                 ...                     ...               ...
# 27162599  1722200329620             604030037.0              0.00
# 27162600  1722200326715             604260016.0              0.00
# 27162601  1722200314769             604610017.0              0.00
# 27162602  1722200313746             604230010.0              0.00
# 27162603  1722200340652             604030061.0              0.00
#
#           codigo_uf_municipio     cns_paciente  idade sexo  raca_cor  \
# 0                      120020  {{{}||     19    M         3
# 1                      120040  {{~~|     14    M         3
# 2                      120040  {}{{~{     48    F         3
# 3                      120040  {{~~~||     10    F         3
# 4                      120040  {{~{{|}      8    F         3
# ...                       ...              ...    ...  ...       ...
# 27162599               170210  {~{|~{{     37    M         1
# 27162600               172100  {{|{|{}{     42    M         1
# 27162601               172100  {{}|}||     11    M         1
# 27162602               172100  {{{{}     52    F         3
# 27162603               171820  {{{~|}     73    M         3
#
#           motivo_saida_permanencia  data_ocorrencia cid_principal  peso  \
# 0                               21              NaN          F208    83
# 1                               21              NaN          F200   713
# 2                               21              NaN          E232   120
# 3                               21              NaN          E228    37
# 4                               21              NaN          E228    29
# ...                            ...              ...           ...   ...
# 27162599                        21              NaN          E221   800
# 27162600                        21              NaN          N180    68
# 27162601                        21              NaN          E230    28
# 27162602                        21              NaN          F200    58
# 27162603                        21              NaN          G20     52
#
#           altura indicador_transplante  quantidade_transplantes  \
# 0            177                     N                        0
# 1            160                     N                        0
# 2            158                     N                        0
# 3            144                     N                        0
# 4            117                     N                        0
# ...          ...                   ...                      ...
# 27162599     180                     N                        0
# 27162600     171                     N                        0
# 27162601     134                     N                        0
# 27162602     160                     N                        0
# 27162603     160                     N                        0
#
#          indicador_gestante cid_principal_main_categ CID10  \
# 0                         N                      F20   F20
# 1                         N                      F20   F20
# 2                         N                      E23   E23
# 3                         N                      E22   E22
# 4                         N                      E22   E22
# ...                     ...                      ...   ...
# 27162599                  N                      E22   E22
# 27162600                  N                      N18   N18
# 27162601                  N                      E23   E23
# 27162602                  N                      F20   F20
# 27162603                  N                      G20   G20
#
#                                  cid10_main_descricao
# 0                                       Esquizofrenia
# 1                                       Esquizofrenia
# 2         Hipofunção e outros transtornos da hipófise
# 3                             Hiperfunção da hipófise
# 4                             Hiperfunção da hipófise
# ...                                               ...
# 27162599                      Hiperfunção da hipófise
# 27162600                  Insuficiência renal crônica
# 27162601  Hipofunção e outros transtornos da hipófise
# 27162602                                Esquizofrenia
# 27162603                          Doença de Parkinson
#
# [27162604 rows x 19 columns]

# %% [markdown]
# ### Add Procedimentos (SIGTAP)

# %%
procedimentos = pd.read_csv('../data/external/procedimentos-sigtap.csv', sep = ';')
procedimentos['procedimento_principal'] = procedimentos['procedimento_principal'].astype('str')

procedimentos
# Out:
#      procedimento_principal                   procedimento_principal_descricao
# 0                 101010010  ATIVIDADE EDUCATIVA / ORIENTACAO EM GRUPO NA A...
# 1                 101010028  ATIVIDADE EDUCATIVA / ORIENTACAO EM GRUPO NA A...
# 2                 101010036       PRATICA CORPORAL / ATIVIDADE FISICA EM GRUPO
# 3                 101010044  PRATICAS CORPORAIS EM MEDICINA TRADICIONAL CHI...
# 4                 101010052                                TERAPIA COMUNITARIA
# ...                     ...                                                ...
# 5555              905010035  OCI AVALIACAO INICIAL EM OFTALMOLOGIA - A PART...
# 5556              905010043             OCI AVALIACAO DE RETINOPATIA DIABETICA
# 5557              905010051  OCI AVALIACAO INICIAL PARA ONCOLOGIA OFTALMOLO...
# 5558              905010060    OCI AVALIACAO DIAGNOSTICA EM NEURO OFTALMOLOGIA
# 5559              905010078              OCI EXAMES OFTALMOLOGICOS SOB SEDACAO
#
# [5560 rows x 2 columns]

# %%
combined_df['procedimento_principal'] = combined_df['procedimento_principal'].astype(str).str.split('.').str[0]
combined_df = pd.merge(combined_df, procedimentos, how = 'left', on = 'procedimento_principal')
combined_df.head(10)
# Out:
#      numero_apac procedimento_principal  valor_total_apac  \
# 0  1221200228260              604230028              0.00
# 1  1221200222231              604230028              0.00
# 2  1221200245089              604100019              0.00
# 3  1221200245232              604110030            256.58
# 4  1221200251854              604110030            256.58
# 5  1221200223870              604110030            256.58
# 6  1222200004014              604400012             10.08
# 7  1221200250358              604470045              0.00
# 8  1221200266506              604540019              0.00
# 9  1222200001462              604510020              9.90
#
#    codigo_uf_municipio     cns_paciente  idade sexo  raca_cor  \
# 0               120020  {{{}||     19    M         3
# 1               120040  {{~~|     14    M         3
# 2               120040  {}{{~{     48    F         3
# 3               120040  {{~~~||     10    F         3
# 4               120040  {{~{{|}      8    F         3
# 5               120040  {~}{|~      8    F         3
# 6               120020  {}{|{|{     78    M         4
# 7               120040  {{}{|     65    F         3
# 8               120040  {|{||~{     70    M        99
# 9               120040  {{~{|     11    M         3
#
#    motivo_saida_permanencia  data_ocorrencia cid_principal  peso  altura  \
# 0                        21              NaN          F208    83     177
# 1                        21              NaN          F200   713     160
# 2                        21              NaN          E232   120     158
# 3                        21              NaN          E228    37     144
# 4                        21              NaN          E228    29     117
# 5                        21              NaN          E228    28     123
# 6                        21              NaN          N180    60     160
# 7                        21              NaN          N180    55       0
# 8                        21              NaN          G122    85     175
# 9                        21              NaN          F840    44     150
#
#   indicador_transplante  quantidade_transplantes indicador_gestante  \
# 0                     N                        0                  N
# 1                     N                        0                  N
# 2                     N                        0                  N
# 3                     N                        0                  N
# 4                     N                        0                  N
# 5                     N                        0                  N
# 6                     N                        0                  N
# 7                     N                        0                  N
# 8                     N                        0                  N
# 9                     N                        0                  N
#
#   cid_principal_main_categ CID10  \
# 0                      F20   F20
# 1                      F20   F20
# 2                      E23   E23
# 3                      E22   E22
# 4                      E22   E22
# 5                      E22   E22
# 6                      N18   N18
# 7                      N18   N18
# 8                      G12   G12
# 9                      F84   F84
#
#                               cid10_main_descricao  \
# 0                                    Esquizofrenia
# 1                                    Esquizofrenia
# 2      Hipofunção e outros transtornos da hipófise
# 3                          Hiperfunção da hipófise
# 4                          Hiperfunção da hipófise
# 5                          Hiperfunção da hipófise
# 6                      Insuficiência renal crônica
# 7                      Insuficiência renal crônica
# 8  Atrofia muscular espinal e síndromes correlatas
# 9           Transtornos globais do desenvolvimento
#
#                     procedimento_principal_descricao
# 0                  OLANZAPINA 10 MG (POR COMPRIMIDO)
# 1                  OLANZAPINA 10 MG (POR COMPRIMIDO)
# 2  DESMOPRESSINA 0,1 MG/ML APLICACAO NASAL (POR F...
# 3  LEUPRORRELINA 3,75 MG INJETAVEL (POR FRASCO-AM...
# 4  LEUPRORRELINA 3,75 MG INJETAVEL (POR FRASCO-AM...
# 5  LEUPRORRELINA 3,75 MG INJETAVEL (POR FRASCO-AM...
# 6                  SEVELAMER 800 MG (POR COMPRIMIDO)
# 7  ALFAEPOETINA 4.000 UI INJETAVEL (POR FRASCO-AM...
# 8                     RILUZOL 50 MG (POR COMPRIMIDO)
# 9                  RISPERIDONA 2 MG (POR COMPRIMIDO)

# %% [markdown]
# ### Add Estados

# %%
codigo_estados = pd.read_csv("../data/external/estados.csv")
codigo_estados.rename({'COD':'codigo_estado', 'NOME':'nome_estado', 'SIGLA':'sigla_estado'}, axis = 1, inplace=True)

codigo_estados
# Out:
#     codigo_estado          nome_estado sigla_estado
# 0              35            São Paulo           SP
# 1              41               Paraná           PR
# 2              42       Santa Catarina           SC
# 3              43    Rio Grande do Sul           RS
# 4              50   Mato Grosso do Sul           MS
# 5              11             Rondônia           RO
# 6              12                 Acre           AC
# 7              13             Amazonas           AM
# 8              14              Roraima           RR
# 9              15                 Pará           PA
# 10             16                Amapá           AP
# 11             17            Tocantins           TO
# 12             21             Maranhão           MA
# 13             24  Rio Grande do Norte           RN
# 14             25              Paraíba           PB
# 15             26           Pernambuco           PE
# 16             27              Alagoas           AL
# 17             28              Sergipe           SE
# 18             29                Bahia           BA
# 19             31         Minas Gerais           MG
# 20             33       Rio de Janeiro           RJ
# 21             51          Mato Grosso           MT
# 22             52                Goiás           GO
# 23             53     Distrito Federal           DF
# 24             22                Piauí           PI
# 25             23                Ceará           CE
# 26             32       Espírito Santo           ES

# %%
combined_df['codigo_estado'] = combined_df.astype(str).codigo_uf_municipio.str[:2].astype(int)

# %%
combined_df = pd.merge(combined_df, codigo_estados, how = 'left', on = 'codigo_estado')
combined_df
# Out:
#             numero_apac procedimento_principal  valor_total_apac  \
# 0         1221200228260              604230028              0.00
# 1         1221200222231              604230028              0.00
# 2         1221200245089              604100019              0.00
# 3         1221200245232              604110030            256.58
# 4         1221200251854              604110030            256.58
# ...                 ...                    ...               ...
# 27162599  1722200329620              604030037              0.00
# 27162600  1722200326715              604260016              0.00
# 27162601  1722200314769              604610017              0.00
# 27162602  1722200313746              604230010              0.00
# 27162603  1722200340652              604030061              0.00
#
#           codigo_uf_municipio     cns_paciente  idade sexo  raca_cor  \
# 0                      120020  {{{}||     19    M         3
# 1                      120040  {{~~|     14    M         3
# 2                      120040  {}{{~{     48    F         3
# 3                      120040  {{~~~||     10    F         3
# 4                      120040  {{~{{|}      8    F         3
# ...                       ...              ...    ...  ...       ...
# 27162599               170210  {~{|~{{     37    M         1
# 27162600               172100  {{|{|{}{     42    M         1
# 27162601               172100  {{}|}||     11    M         1
# 27162602               172100  {{{{}     52    F         3
# 27162603               171820  {{{~|}     73    M         3
#
#           motivo_saida_permanencia  data_ocorrencia  ...  \
# 0                               21              NaN  ...
# 1                               21              NaN  ...
# 2                               21              NaN  ...
# 3                               21              NaN  ...
# 4                               21              NaN  ...
# ...                            ...              ...  ...
# 27162599                        21              NaN  ...
# 27162600                        21              NaN  ...
# 27162601                        21              NaN  ...
# 27162602                        21              NaN  ...
# 27162603                        21              NaN  ...
#
#          indicador_transplante  quantidade_transplantes  indicador_gestante  \
# 0                            N                        0                   N
# 1                            N                        0                   N
# 2                            N                        0                   N
# 3                            N                        0                   N
# 4                            N                        0                   N
# ...                        ...                      ...                 ...
# 27162599                     N                        0                   N
# 27162600                     N                        0                   N
# 27162601                     N                        0                   N
# 27162602                     N                        0                   N
# 27162603                     N                        0                   N
#
#          cid_principal_main_categ  CID10  \
# 0                             F20    F20
# 1                             F20    F20
# 2                             E23    E23
# 3                             E22    E22
# 4                             E22    E22
# ...                           ...    ...
# 27162599                      E22    E22
# 27162600                      N18    N18
# 27162601                      E23    E23
# 27162602                      F20    F20
# 27162603                      G20    G20
#
#                                  cid10_main_descricao  \
# 0                                       Esquizofrenia
# 1                                       Esquizofrenia
# 2         Hipofunção e outros transtornos da hipófise
# 3                             Hiperfunção da hipófise
# 4                             Hiperfunção da hipófise
# ...                                               ...
# 27162599                      Hiperfunção da hipófise
# 27162600                  Insuficiência renal crônica
# 27162601  Hipofunção e outros transtornos da hipófise
# 27162602                                Esquizofrenia
# 27162603                          Doença de Parkinson
#
#                            procedimento_principal_descricao codigo_estado  \
# 0                         OLANZAPINA 10 MG (POR COMPRIMIDO)            12
# 1                         OLANZAPINA 10 MG (POR COMPRIMIDO)            12
# 2         DESMOPRESSINA 0,1 MG/ML APLICACAO NASAL (POR F...            12
# 3         LEUPRORRELINA 3,75 MG INJETAVEL (POR FRASCO-AM...            12
# 4         LEUPRORRELINA 3,75 MG INJETAVEL (POR FRASCO-AM...            12
# ...                                                     ...           ...
# 27162599                CABERGOLINA 0,5 MG (POR COMPRIMIDO)            17
# 27162600  SACARATO DE HIDROXIDO FERRICO 100 MG INJETAVEL...            17
# 27162601     SOMATROPINA 4 UI INJETAVEL (POR FRASCO-AMPOLA)            17
# 27162602                   OLANZAPINA 5 MG (POR COMPRIMIDO)            17
# 27162603                   PRAMIPEXOL 1 MG (POR COMPRIMIDO)            17
#
#          nome_estado sigla_estado
# 0               Acre           AC
# 1               Acre           AC
# 2               Acre           AC
# 3               Acre           AC
# 4               Acre           AC
# ...              ...          ...
# 27162599   Tocantins           TO
# 27162600   Tocantins           TO
# 27162601   Tocantins           TO
# 27162602   Tocantins           TO
# 27162603   Tocantins           TO
#
# [27162604 rows x 23 columns]

# %% [markdown]
# ### Add motivo saída

# %%
motivo_saida = pd.read_csv('../data/external/motivo-saida.csv')
motivo_saida['motivo_saida'] = motivo_saida['motivo_saida'].astype(int)
combined_df = pd.merge(combined_df, motivo_saida, how = 'left', left_on = 'motivo_saida_permanencia', right_on = 'motivo_saida')
combined_df
# Out:
#             numero_apac procedimento_principal  valor_total_apac  \
# 0         1221200228260              604230028              0.00
# 1         1221200222231              604230028              0.00
# 2         1221200245089              604100019              0.00
# 3         1221200245232              604110030            256.58
# 4         1221200251854              604110030            256.58
# ...                 ...                    ...               ...
# 27162599  1722200329620              604030037              0.00
# 27162600  1722200326715              604260016              0.00
# 27162601  1722200314769              604610017              0.00
# 27162602  1722200313746              604230010              0.00
# 27162603  1722200340652              604030061              0.00
#
#           codigo_uf_municipio     cns_paciente  idade sexo  raca_cor  \
# 0                      120020  {{{}||     19    M         3
# 1                      120040  {{~~|     14    M         3
# 2                      120040  {}{{~{     48    F         3
# 3                      120040  {{~~~||     10    F         3
# 4                      120040  {{~{{|}      8    F         3
# ...                       ...              ...    ...  ...       ...
# 27162599               170210  {~{|~{{     37    M         1
# 27162600               172100  {{|{|{}{     42    M         1
# 27162601               172100  {{}|}||     11    M         1
# 27162602               172100  {{{{}     52    F         3
# 27162603               171820  {{{~|}     73    M         3
#
#           motivo_saida_permanencia  data_ocorrencia  ... indicador_gestante  \
# 0                               21              NaN  ...                  N
# 1                               21              NaN  ...                  N
# 2                               21              NaN  ...                  N
# 3                               21              NaN  ...                  N
# 4                               21              NaN  ...                  N
# ...                            ...              ...  ...                ...
# 27162599                        21              NaN  ...                  N
# 27162600                        21              NaN  ...                  N
# 27162601                        21              NaN  ...                  N
# 27162602                        21              NaN  ...                  N
# 27162603                        21              NaN  ...                  N
#
#           cid_principal_main_categ  CID10  \
# 0                              F20    F20
# 1                              F20    F20
# 2                              E23    E23
# 3                              E22    E22
# 4                              E22    E22
# ...                            ...    ...
# 27162599                       E22    E22
# 27162600                       N18    N18
# 27162601                       E23    E23
# 27162602                       F20    F20
# 27162603                       G20    G20
#
#                                  cid10_main_descricao  \
# 0                                       Esquizofrenia
# 1                                       Esquizofrenia
# 2         Hipofunção e outros transtornos da hipófise
# 3                             Hiperfunção da hipófise
# 4                             Hiperfunção da hipófise
# ...                                               ...
# 27162599                      Hiperfunção da hipófise
# 27162600                  Insuficiência renal crônica
# 27162601  Hipofunção e outros transtornos da hipófise
# 27162602                                Esquizofrenia
# 27162603                          Doença de Parkinson
#
#                            procedimento_principal_descricao codigo_estado  \
# 0                         OLANZAPINA 10 MG (POR COMPRIMIDO)            12
# 1                         OLANZAPINA 10 MG (POR COMPRIMIDO)            12
# 2         DESMOPRESSINA 0,1 MG/ML APLICACAO NASAL (POR F...            12
# 3         LEUPRORRELINA 3,75 MG INJETAVEL (POR FRASCO-AM...            12
# 4         LEUPRORRELINA 3,75 MG INJETAVEL (POR FRASCO-AM...            12
# ...                                                     ...           ...
# 27162599                CABERGOLINA 0,5 MG (POR COMPRIMIDO)            17
# 27162600  SACARATO DE HIDROXIDO FERRICO 100 MG INJETAVEL...            17
# 27162601     SOMATROPINA 4 UI INJETAVEL (POR FRASCO-AMPOLA)            17
# 27162602                   OLANZAPINA 5 MG (POR COMPRIMIDO)            17
# 27162603                   PRAMIPEXOL 1 MG (POR COMPRIMIDO)            17
#
#          nome_estado sigla_estado motivo_saida  \
# 0               Acre           AC           21
# 1               Acre           AC           21
# 2               Acre           AC           21
# 3               Acre           AC           21
# 4               Acre           AC           21
# ...              ...          ...          ...
# 27162599   Tocantins           TO           21
# 27162600   Tocantins           TO           21
# 27162601   Tocantins           TO           21
# 27162602   Tocantins           TO           21
# 27162603   Tocantins           TO           21
#
#                                      motivo_saida_descricao
# 0          Permanência por características próprias da d...
# 1          Permanência por características próprias da d...
# 2          Permanência por características próprias da d...
# 3          Permanência por características próprias da d...
# 4          Permanência por características próprias da d...
# ...                                                     ...
# 27162599   Permanência por características próprias da d...
# 27162600   Permanência por características próprias da d...
# 27162601   Permanência por características próprias da d...
# 27162602   Permanência por características próprias da d...
# 27162603   Permanência por características próprias da d...
#
# [27162604 rows x 25 columns]

# %% [markdown]
# ### Load
#
# Our load will be just export to `.csv`. Nice :)

# %%
codes, uniques = pd.factorize(combined_df['cns_paciente'])
combined_df['cns_coded'] = ['cns_' + f'{code:08}' for code in codes]

combined_df.to_csv('../data/processed/apac-am-2022.csv')

# %%
file_path = Path('../data/processed/apac-am-2022.csv')
size_bytes = file_path.stat().st_size
print('../data/processed/apac-am-2022.csv')
print(f"Size in GB: {size_bytes / (1024 ** 3):.2f}")
# Out:
# ../data/processed/apac-am-2022.csv
# Size in GB: 6.76

# %%
toy_data = combined_df.sample(frac = 0.1, axis = 0)
toy_data.to_csv('../data/processed/apac-am-2022-toy.csv', index = False)

file_path = Path('../data/processed/apac-am-2022-toy.csv')
size_bytes = file_path.stat().st_size
print('../data/processed/apac-am-2022-toy.csv')
print(f"Size in GB: {size_bytes / (1024 ** 3):.2f}")
# Out:
# ../data/processed/apac-am-2022-toy.csv
# Size in GB: 0.65
